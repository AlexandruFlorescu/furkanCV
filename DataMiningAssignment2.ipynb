# %% [markdown]
# # Affinity Analysis for 3 Items

# %% [markdown]
# ## Use the Affinity Analysis Example and the Affinity Dataset to coplete Parts A to G below.

# %% [markdown]
# ### Part A: Write down a statement that best describes the support of rules containing three items at a time. For example:  If a person buys cheese and apples, then they are likely to purchase bananas.

# %% [markdown]
# Express your answer as P(X, Y, Z) = P(X|Y,Z)P(Y|Z)P(Z)

# %% [markdown]
# ### Part B: Write down a statement that best describes the confidence of rules containing three items at a time. i.e. given x and Y, a transaction also contains Z. For example:  If a person buys  cheese and apples, then they are likely to purchase  bananas.

# %% [markdown]
# Express your answer as P(XY|Z) = P(XY|Z)/P(Z)

# %% [markdown]
# ### Part C: Revise the code developed in the Affinity Example to calculate the support and confidence of rules containing three items at a time. For example:  If a person buys cheese and apples, then they are likely to purchase bananas.

# %% [markdown]
# #### Load the dataset

# %%
import numpy as np
import pandas as pd # read xls
dataset_filename = "ReducedData.xlsx"
X = pd.read_excel(dataset_filename)
n_samples, n_features = X.shape 
print("This dataset has {0} samples and {1} features".format(n_samples, n_features))
# Out:
# This dataset has 2897 samples and 12 features

# %% [markdown]
# #### List the features

# %%
# The names of the features, for your reference.
features = list(X.columns)
print(features)
# Out:
# ['household_key', 'BASKET_ID', 'DAY', 'PRODUCT_ID', 'QUANTITY', 'SALES_VALUE', 'STORE_ID', 'RETAIL_DISC', 'TRANS_TIME', 'WEEK_NO', 'COUPON_DISC', 'COUPON_MATCH_DISC']

# %% [markdown]
# #### Print transactions
#
# Print the first five rows of the dataset to get a sense of what the dataset looks like. The result will show you which items were bought in the first five transactions listed

# %%
print(X.head())
# Out:
#    household_key    BASKET_ID  DAY  PRODUCT_ID  QUANTITY  SALES_VALUE  \
# 0           1228  29046618323  157       20000         1         3.49
# 1            358  30707611686  247       20000         1         3.49
# 2           1675  30760265177  250       20000         1         0.99
# 3           1420  30591251330  238       20000         1         1.54
# 4            486  30636771192  242       20000         2         1.98
#
#    STORE_ID  RETAIL_DISC  TRANS_TIME  WEEK_NO  COUPON_DISC  COUPON_MATCH_DISC
# 0      3313         0.00        2213       23          0.0                0.0
# 1      3266         0.00        1211       36          0.0                0.0
# 2      3235         0.00         936       36          0.0                0.0
# 3      3297         0.00        1342       35          0.0                0.0
# 4      3217        -0.52        1411       35          0.0                0.0

# %% [markdown]
# #### Compute the Support and Confidence

# %% [markdown]
# Compute the Support and Confidence of the rule "If a person buys cheese and apples, then they are likely to purchase bananas."

# %%
# Get a list with all the products
products = []
for index, sale in X.iterrows():
    products.append(int(sale['PRODUCT_ID']))
products = list(set(products))

# We create a dictionary holding which products each household bought
whoBought = {}
for index, sale in X.iterrows():
    if int(sale['household_key']) in whoBought:
        whoBought[int(sale['household_key'])].append(int(sale['PRODUCT_ID'])) 
    else:
        whoBought[int(sale['household_key'])] = [int(sale['PRODUCT_ID'])]

# Remove duplicates?
for key in whoBought.keys():
    whoBought[key] = list(set(whoBought[key]))

### Compute the sale counts for each product separately
boughtCount = {key:len(whoBought[key]) for key in whoBought.keys()}
###

for key in whoBought.keys():
    print("household_{0} bought products {1}".format(key, whoBought[key]))
# Out:
# household_1536 bought products [30000, 70000, 90000, 100000, 120000]
# household_1409 bought products [20000, 40000, 60000, 80000, 100000, 120000, 160000, 180000, 200000, 50000, 30000, 70000, 90000, 110000, 130000, 150000, 170000, 190000]
# household_2 bought products [30000, 170000, 60000, 100000]
# household_2181 bought products [120000]
# household_2182 bought products [20000, 40000, 60000, 80000, 100000, 120000, 140000, 160000, 200000, 50000, 30000, 70000, 90000, 110000, 130000, 150000, 190000]
# household_1722 bought products [40000, 200000, 80000, 120000, 190000, 70000]
# household_1032 bought products [20000, 40000, 60000, 80000, 100000, 120000, 140000, 160000, 200000, 50000, 30000, 70000, 90000, 110000, 130000, 150000, 170000, 190000]
# household_364 bought products [20000, 40000, 60000, 80000, 100000, 120000, 140000, 50000, 30000, 70000, 90000, 110000, 130000, 190000]
# household_1675 bought products [20000, 40000, 60000, 80000, 100000, 120000, 140000, 160000, 180000, 200000, 50000, 30000, 70000, 90000, 110000, 130000, 150000, 170000, 190000]
# household_1420 bought products [20000, 40000, 60000, 80000, 100000, 120000, 160000, 200000, 50000, 30000, 70000, 90000, 110000, 130000]
# household_52 bought products [60000, 150000, 70000]
# household_1166 bought products [70000, 80000]
# household_143 bought products [110000]
# household_2498 bought products [110000]
# household_2137 bought products [150000]
# household_20 bought products [20000, 150000]
# household_2197 bought products [120000]
# household_1814 bought products [20000, 40000, 60000, 80000, 100000, 120000, 140000, 160000, 180000, 200000, 50000, 30000, 70000, 90000, 110000, 130000, 150000, 190000]
# household_1113 bought products [20000, 40000, 60000, 80000, 100000, 160000, 200000, 50000, 30000, 70000, 90000, 110000, 130000, 170000]
# household_1176 bought products [20000, 200000, 30000, 70000, 90000, 110000, 130000, 170000, 190000]
# household_1476 bought products [20000, 40000, 80000, 120000, 50000, 30000, 70000, 90000, 110000, 150000]
# household_922 bought products [40000, 60000, 100000, 120000, 140000, 30000, 70000, 50000, 90000, 110000]
# household_284 bought products [20000, 40000, 80000, 140000, 50000, 30000, 70000, 130000]
# household_1182 bought products [20000, 40000, 60000, 80000, 100000, 120000, 140000, 160000, 180000, 200000, 50000, 30000, 70000, 90000, 110000, 130000, 150000, 190000]
# household_601 bought products [20000, 40000, 60000, 80000, 200000, 50000, 30000, 70000, 90000, 110000, 190000]
# household_32 bought products [20000, 40000, 60000, 80000, 100000, 120000, 50000, 30000, 70000, 90000, 110000, 170000]
# household_163 bought products [70000, 80000]
# household_1957 bought products [20000, 40000, 60000, 80000, 100000, 120000, 140000, 160000, 200000, 50000, 30000, 70000, 90000, 110000, 130000, 150000, 170000, 190000]
# household_926 bought products [130000]
# household_1959 bought products [40000, 60000, 80000, 100000, 120000, 160000, 200000, 30000, 70000, 50000, 90000, 150000, 170000]
# household_990 bought products [80000]
# household_540 bought products [130000]
# household_682 bought products [120000]
# household_683 bought products [40000, 60000, 80000, 120000, 200000, 30000, 70000, 50000, 90000, 110000, 130000, 170000]
# household_882 bought products [40000, 80000, 30000, 90000, 50000, 70000, 150000]
# household_2478 bought products [80000]
# household_1071 bought products [30000, 140000, 60000, 80000, 100000]
# household_1076 bought products [30000, 180000]
# household_1894 bought products [20000, 40000, 60000, 80000, 100000, 200000, 50000, 30000, 70000, 110000, 130000, 190000]
# household_2230 bought products [40000, 60000, 80000, 100000, 120000, 180000, 200000, 30000, 70000, 50000, 90000, 110000, 130000]
# household_2231 bought products [30000, 200000, 70000]
# household_2104 bought products [110000, 160000, 200000]
# household_1332 bought products [30000, 120000]
# household_1338 bought products [20000, 40000, 60000, 80000, 100000, 120000, 140000, 160000, 50000, 30000, 70000, 90000, 110000, 130000, 150000, 170000, 190000]
# household_62 bought products [20000, 40000, 60000, 80000, 100000, 160000, 200000, 50000, 30000, 70000, 90000, 110000, 130000]
# household_1855 bought products [90000, 130000]
# household_2114 bought products [50000]
# household_715 bought products [150000, 180000]
# household_1988 bought products [20000, 40000, 60000, 80000, 100000, 120000, 160000, 180000, 200000, 50000, 30000, 70000, 90000, 110000, 130000, 190000]
# household_840 bought products [20000, 40000, 100000, 140000, 200000, 30000, 70000, 90000, 110000, 190000]
# household_908 bought products [60000, 150000]
# household_203 bought products [20000, 40000, 80000, 100000, 120000, 50000, 30000, 70000, 90000, 110000, 130000, 150000, 190000]
# household_1228 bought products [20000, 40000, 60000, 80000, 120000, 70000, 110000, 130000, 170000, 190000]
# household_464 bought products [30000]
# household_849 bought products [40000, 60000, 100000, 70000, 110000, 190000]
# household_596 bought products [180000, 30000, 50000, 70000, 150000, 110000, 130000, 170000]
# household_1227 bought products [170000]
# household_985 bought products [60000, 120000, 30000, 70000, 190000, 90000]
# household_2269 bought products [40000, 170000, 90000]
# household_606 bought products [50000]
# household_997 bought products [20000, 40000, 60000, 80000, 100000, 120000, 140000, 160000, 180000, 200000, 50000, 30000, 70000, 90000, 110000, 130000, 150000, 170000, 190000]
# household_2144 bought products [20000, 40000, 60000, 80000, 100000, 120000, 200000, 50000, 30000, 70000, 90000, 110000, 150000, 170000]
# household_212 bought products [160000, 200000, 60000, 100000, 50000, 90000]
# household_486 bought products [20000, 40000, 60000, 80000, 100000, 140000, 160000, 180000, 200000, 50000, 30000, 70000, 90000, 110000, 130000, 190000]
# household_358 bought products [20000, 40000, 60000, 80000, 70000, 50000, 90000]
# household_1559 bought products [40000, 60000, 80000, 70000, 50000, 90000, 110000, 150000]
# household_748 bought products [30000]
# household_1128 bought products [70000, 200000, 100000]
# household_2034 bought products [30000, 40000]
# household_755 bought products [30000, 40000, 60000, 200000, 120000]
# household_630 bought products [30000, 40000, 90000]
# household_121 bought products [20000, 40000, 60000, 80000, 100000, 140000, 200000, 50000, 30000, 70000, 90000, 110000, 190000]
# household_506 bought products [60000, 80000, 100000, 120000, 200000, 30000, 90000, 50000, 110000, 170000]
# household_1915 bought products [50000, 70000]
# household_1920 bought products [140000]

# %%
# Compute the rule for products 20000, 40000, 60000
c2, c4, c6 = (0,0,0)
for h in whoBought.keys():
    if 20000 in whoBought[h]:
        c2 += 1
    if 40000 in whoBought[h]:
        c4 += 1
    if 60000 in whoBought[h]:
        c6 += 1
        
rule_valid = 0
rule_invalid = 0
for h in whoBought.keys():
    if 20000 in whoBought[h]: # this person bought Cheese
        if 40000 in whoBought[h]: # this person bought Cheese and Apples
            if 60000 in whoBought[h]: # this person bought Cheese and Apples AND Bananas
                rule_valid +=1
            else:
                rule_invalid +=1
                
print("{0} cases of the rule being valid were discovered".format(rule_valid))
print("{0} cases of the rule being invalid were discovered".format(rule_invalid))
# Out:
# 13 cases of the rule being valid were discovered
# 13 cases of the rule being invalid were discovered

# %%
support = rule_valid  # The Support is the number of times the rule is discovered.
confidence2 = rule_valid / c2
confidence4 = rule_valid / c4
confidence6 = rule_valid / c6
print(confidence2, confidence4, confidence6)
# Out:
# 0.4642857142857143 0.34210526315789475 0.8125

# %% [markdown]
# #### Compute these statistics for all rules in the dataset

# %%
from collections import defaultdict
# Now compute for all possible rules
valid_rules = defaultdict(int)
invalid_rules = defaultdict(int)
num_occurences = defaultdict(int)

# Compute the Support for each products combinations
for premiseA in products:
    for premiseB in products:
        if premiseB == premiseA: continue
        for conclusion in products:
            if conclusion == premiseA or conclusion == premiseB: continue
            for h in whoBought.keys():
                if premiseA in whoBought[h] and premiseB in whoBought[h]:
                    num_occurences[premiseA, premiseB] += 1
                    if conclusion in whoBought[h]:
                        valid_rules[(premiseA, premiseB, conclusion)] += 1
                    else:
                        invalid_rules[(premiseA, premiseB, conclusion)] += 1


support = valid_rules
confidence = defaultdict(float)
for premiseA, premiseB, conclusion in valid_rules.keys():
    confidence[(premiseA, premiseB, conclusion)] = valid_rules[(premiseA, premiseB, conclusion)] / num_occurences[premiseA, premiseB]
    
for premiseA, premiseB, conclusion in confidence:
    print("Rule: If a person buys {0} and {1} they will also buy {2}".format(premiseA, premiseB, conclusion))
    print(" - Confidence: {0:.3f}".format(confidence[(premiseA, premiseB, conclusion)]))
    print(" - Support: {0}".format(support[(premiseA, premiseB, conclusion)]))
    print("")
# Out:
# Rule: If a person buys 120000 and 60000 they will also buy 150000
#  - Confidence: 0.029
#  - Support: 11
#
# Rule: If a person buys 190000 and 100000 they will also buy 110000
#  - Confidence: 0.059
#  - Support: 17
#
# Rule: If a person buys 170000 and 20000 they will also buy 100000
#  - Confidence: 0.048
#  - Support: 9
#
# Rule: If a person buys 110000 and 120000 they will also buy 50000
#  - Confidence: 0.056
#  - Support: 20
#
# Rule: If a person buys 90000 and 50000 they will also buy 80000
#  - Confidence: 0.055
#  - Support: 28
#
# Rule: If a person buys 150000 and 80000 they will also buy 30000
#  - Confidence: 0.055
#  - Support: 14
#
# Rule: If a person buys 40000 and 190000 they will also buy 110000
#  - Confidence: 0.056
#  - Support: 19
#
# Rule: If a person buys 140000 and 200000 they will also buy 20000
#  - Confidence: 0.059
#  - Support: 10
#
# Rule: If a person buys 110000 and 180000 they will also buy 130000
#  - Confidence: 0.059
#  - Support: 9
#
# Rule: If a person buys 170000 and 190000 they will also buy 180000
#  - Confidence: 0.022
#  - Support: 3
#
# Rule: If a person buys 160000 and 110000 they will also buy 30000
#  - Confidence: 0.055
#  - Support: 14
#
# Rule: If a person buys 140000 and 130000 they will also buy 80000
#  - Confidence: 0.059
#  - Support: 11
#
# Rule: If a person buys 20000 and 50000 they will also buy 190000
#  - Confidence: 0.039
#  - Support: 16
#
# Rule: If a person buys 30000 and 50000 they will also buy 180000
#  - Confidence: 0.018
#  - Support: 9
#
# Rule: If a person buys 60000 and 130000 they will also buy 90000
#  - Confidence: 0.053
#  - Support: 17
#
# Rule: If a person buys 160000 and 170000 they will also buy 200000
#  - Confidence: 0.051
#  - Support: 7
#
# Rule: If a person buys 200000 and 90000 they will also buy 120000
#  - Confidence: 0.038
#  - Support: 15
#
# Rule: If a person buys 140000 and 190000 they will also buy 180000
#  - Confidence: 0.025
#  - Support: 5
#
# Rule: If a person buys 40000 and 80000 they will also buy 170000
#  - Confidence: 0.023
#  - Support: 12
#
# Rule: If a person buys 160000 and 50000 they will also buy 40000
#  - Confidence: 0.055
#  - Support: 15
#
# Rule: If a person buys 200000 and 160000 they will also buy 90000
#  - Confidence: 0.055
#  - Support: 15
#
# Rule: If a person buys 60000 and 150000 they will also buy 140000
#  - Confidence: 0.034
#  - Support: 8
#
# Rule: If a person buys 40000 and 130000 they will also buy 90000
#  - Confidence: 0.050
#  - Support: 18
#
# Rule: If a person buys 160000 and 90000 they will also buy 170000
#  - Confidence: 0.029
#  - Support: 8
#
# Rule: If a person buys 180000 and 110000 they will also buy 120000
#  - Confidence: 0.046
#  - Support: 7
#
# Rule: If a person buys 70000 and 50000 they will also buy 170000
#  - Confidence: 0.022
#  - Support: 12
#
# Rule: If a person buys 20000 and 130000 they will also buy 170000
#  - Confidence: 0.026
#  - Support: 9
#
# Rule: If a person buys 120000 and 80000 they will also buy 160000
#  - Confidence: 0.032
#  - Support: 12
#
# Rule: If a person buys 130000 and 40000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 21
#
# Rule: If a person buys 190000 and 180000 they will also buy 120000
#  - Confidence: 0.050
#  - Support: 6
#
# Rule: If a person buys 110000 and 140000 they will also buy 60000
#  - Confidence: 0.054
#  - Support: 12
#
# Rule: If a person buys 170000 and 30000 they will also buy 70000
#  - Confidence: 0.051
#  - Support: 13
#
# Rule: If a person buys 130000 and 170000 they will also buy 140000
#  - Confidence: 0.027
#  - Support: 5
#
# Rule: If a person buys 70000 and 130000 they will also buy 190000
#  - Confidence: 0.041
#  - Support: 16
#
# Rule: If a person buys 190000 and 50000 they will also buy 130000
#  - Confidence: 0.051
#  - Support: 14
#
# Rule: If a person buys 90000 and 120000 they will also buy 180000
#  - Confidence: 0.018
#  - Support: 7
#
# Rule: If a person buys 90000 and 120000 they will also buy 70000
#  - Confidence: 0.056
#  - Support: 22
#
# Rule: If a person buys 180000 and 20000 they will also buy 120000
#  - Confidence: 0.050
#  - Support: 6
#
# Rule: If a person buys 170000 and 20000 they will also buy 160000
#  - Confidence: 0.037
#  - Support: 7
#
# Rule: If a person buys 30000 and 180000 they will also buy 150000
#  - Confidence: 0.035
#  - Support: 6
#
# Rule: If a person buys 150000 and 190000 they will also buy 160000
#  - Confidence: 0.053
#  - Support: 9
#
# Rule: If a person buys 100000 and 110000 they will also buy 30000
#  - Confidence: 0.056
#  - Support: 24
#
# Rule: If a person buys 130000 and 20000 they will also buy 170000
#  - Confidence: 0.026
#  - Support: 9
#
# Rule: If a person buys 110000 and 70000 they will also buy 80000
#  - Confidence: 0.049
#  - Support: 26
#
# Rule: If a person buys 70000 and 40000 they will also buy 30000
#  - Confidence: 0.050
#  - Support: 29
#
# Rule: If a person buys 20000 and 60000 they will also buy 100000
#  - Confidence: 0.051
#  - Support: 19
#
# Rule: If a person buys 130000 and 50000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 21
#
# Rule: If a person buys 60000 and 150000 they will also buy 190000
#  - Confidence: 0.038
#  - Support: 9
#
# Rule: If a person buys 20000 and 110000 they will also buy 40000
#  - Confidence: 0.056
#  - Support: 24
#
# Rule: If a person buys 130000 and 170000 they will also buy 180000
#  - Confidence: 0.021
#  - Support: 4
#
# Rule: If a person buys 30000 and 100000 they will also buy 160000
#  - Confidence: 0.032
#  - Support: 15
#
# Rule: If a person buys 130000 and 60000 they will also buy 20000
#  - Confidence: 0.053
#  - Support: 17
#
# Rule: If a person buys 110000 and 190000 they will also buy 50000
#  - Confidence: 0.047
#  - Support: 16
#
# Rule: If a person buys 30000 and 60000 they will also buy 110000
#  - Confidence: 0.049
#  - Support: 24
#
# Rule: If a person buys 40000 and 60000 they will also buy 100000
#  - Confidence: 0.047
#  - Support: 23
#
# Rule: If a person buys 110000 and 50000 they will also buy 180000
#  - Confidence: 0.019
#  - Support: 9
#
# Rule: If a person buys 60000 and 110000 they will also buy 140000
#  - Confidence: 0.026
#  - Support: 12
#
# Rule: If a person buys 160000 and 150000 they will also buy 90000
#  - Confidence: 0.059
#  - Support: 10
#
# Rule: If a person buys 60000 and 40000 they will also buy 130000
#  - Confidence: 0.039
#  - Support: 19
#
# Rule: If a person buys 60000 and 170000 they will also buy 110000
#  - Confidence: 0.050
#  - Support: 12
#
# Rule: If a person buys 40000 and 30000 they will also buy 120000
#  - Confidence: 0.039
#  - Support: 21
#
# Rule: If a person buys 50000 and 150000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 16
#
# Rule: If a person buys 30000 and 90000 they will also buy 160000
#  - Confidence: 0.028
#  - Support: 15
#
# Rule: If a person buys 20000 and 200000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 19
#
# Rule: If a person buys 20000 and 30000 they will also buy 110000
#  - Confidence: 0.056
#  - Support: 24
#
# Rule: If a person buys 50000 and 130000 they will also buy 170000
#  - Confidence: 0.025
#  - Support: 9
#
# Rule: If a person buys 40000 and 160000 they will also buy 140000
#  - Confidence: 0.035
#  - Support: 9
#
# Rule: If a person buys 50000 and 110000 they will also buy 140000
#  - Confidence: 0.025
#  - Support: 12
#
# Rule: If a person buys 200000 and 160000 they will also buy 80000
#  - Confidence: 0.051
#  - Support: 14
#
# Rule: If a person buys 200000 and 70000 they will also buy 150000
#  - Confidence: 0.024
#  - Support: 10
#
# Rule: If a person buys 200000 and 30000 they will also buy 160000
#  - Confidence: 0.033
#  - Support: 14
#
# Rule: If a person buys 120000 and 170000 they will also buy 130000
#  - Confidence: 0.039
#  - Support: 8
#
# Rule: If a person buys 90000 and 160000 they will also buy 140000
#  - Confidence: 0.033
#  - Support: 9
#
# Rule: If a person buys 150000 and 60000 they will also buy 200000
#  - Confidence: 0.042
#  - Support: 10
#
# Rule: If a person buys 150000 and 190000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 10
#
# Rule: If a person buys 170000 and 150000 they will also buy 60000
#  - Confidence: 0.052
#  - Support: 8
#
# Rule: If a person buys 60000 and 200000 they will also buy 50000
#  - Confidence: 0.056
#  - Support: 22
#
# Rule: If a person buys 90000 and 120000 they will also buy 200000
#  - Confidence: 0.038
#  - Support: 15
#
# Rule: If a person buys 50000 and 180000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 9
#
# Rule: If a person buys 40000 and 130000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 21
#
# Rule: If a person buys 70000 and 110000 they will also buy 60000
#  - Confidence: 0.049
#  - Support: 26
#
# Rule: If a person buys 200000 and 100000 they will also buy 130000
#  - Confidence: 0.040
#  - Support: 15
#
# Rule: If a person buys 90000 and 70000 they will also buy 180000
#  - Confidence: 0.015
#  - Support: 8
#
# Rule: If a person buys 20000 and 120000 they will also buy 50000
#  - Confidence: 0.055
#  - Support: 16
#
# Rule: If a person buys 50000 and 40000 they will also buy 200000
#  - Confidence: 0.039
#  - Support: 20
#
# Rule: If a person buys 100000 and 200000 they will also buy 120000
#  - Confidence: 0.037
#  - Support: 14
#
# Rule: If a person buys 160000 and 120000 they will also buy 190000
#  - Confidence: 0.049
#  - Support: 10
#
# Rule: If a person buys 130000 and 50000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 21
#
# Rule: If a person buys 50000 and 60000 they will also buy 120000
#  - Confidence: 0.040
#  - Support: 19
#
# Rule: If a person buys 90000 and 130000 they will also buy 50000
#  - Confidence: 0.053
#  - Support: 18
#
# Rule: If a person buys 30000 and 70000 they will also buy 180000
#  - Confidence: 0.016
#  - Support: 9
#
# Rule: If a person buys 170000 and 200000 they will also buy 80000
#  - Confidence: 0.053
#  - Support: 10
#
# Rule: If a person buys 50000 and 150000 they will also buy 40000
#  - Confidence: 0.055
#  - Support: 15
#
# Rule: If a person buys 30000 and 200000 they will also buy 40000
#  - Confidence: 0.052
#  - Support: 22
#
# Rule: If a person buys 180000 and 30000 they will also buy 130000
#  - Confidence: 0.053
#  - Support: 9
#
# Rule: If a person buys 200000 and 170000 they will also buy 140000
#  - Confidence: 0.021
#  - Support: 4
#
# Rule: If a person buys 180000 and 20000 they will also buy 190000
#  - Confidence: 0.059
#  - Support: 7
#
# Rule: If a person buys 190000 and 180000 they will also buy 130000
#  - Confidence: 0.059
#  - Support: 7
#
# Rule: If a person buys 80000 and 150000 they will also buy 30000
#  - Confidence: 0.055
#  - Support: 14
#
# Rule: If a person buys 100000 and 170000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 12
#
# Rule: If a person buys 100000 and 80000 they will also buy 170000
#  - Confidence: 0.027
#  - Support: 11
#
# Rule: If a person buys 20000 and 170000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 11
#
# Rule: If a person buys 180000 and 80000 they will also buy 90000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 130000 and 70000 they will also buy 150000
#  - Confidence: 0.028
#  - Support: 11
#
# Rule: If a person buys 190000 and 110000 they will also buy 50000
#  - Confidence: 0.047
#  - Support: 16
#
# Rule: If a person buys 120000 and 30000 they will also buy 110000
#  - Confidence: 0.047
#  - Support: 20
#
# Rule: If a person buys 140000 and 200000 they will also buy 160000
#  - Confidence: 0.047
#  - Support: 8
#
# Rule: If a person buys 100000 and 70000 they will also buy 160000
#  - Confidence: 0.033
#  - Support: 15
#
# Rule: If a person buys 140000 and 180000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 5
#
# Rule: If a person buys 180000 and 90000 they will also buy 120000
#  - Confidence: 0.051
#  - Support: 7
#
# Rule: If a person buys 70000 and 120000 they will also buy 50000
#  - Confidence: 0.049
#  - Support: 20
#
# Rule: If a person buys 170000 and 190000 they will also buy 100000
#  - Confidence: 0.044
#  - Support: 6
#
# Rule: If a person buys 190000 and 30000 they will also buy 150000
#  - Confidence: 0.031
#  - Support: 10
#
# Rule: If a person buys 60000 and 180000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 180000 and 50000 they will also buy 190000
#  - Confidence: 0.046
#  - Support: 7
#
# Rule: If a person buys 60000 and 40000 they will also buy 70000
#  - Confidence: 0.057
#  - Support: 28
#
# Rule: If a person buys 170000 and 130000 they will also buy 150000
#  - Confidence: 0.037
#  - Support: 7
#
# Rule: If a person buys 180000 and 110000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 9
#
# Rule: If a person buys 150000 and 140000 they will also buy 100000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 130000 and 50000 they will also buy 200000
#  - Confidence: 0.045
#  - Support: 16
#
# Rule: If a person buys 50000 and 90000 they will also buy 60000
#  - Confidence: 0.053
#  - Support: 27
#
# Rule: If a person buys 200000 and 110000 they will also buy 180000
#  - Confidence: 0.020
#  - Support: 8
#
# Rule: If a person buys 20000 and 120000 they will also buy 40000
#  - Confidence: 0.059
#  - Support: 17
#
# Rule: If a person buys 50000 and 100000 they will also buy 190000
#  - Confidence: 0.035
#  - Support: 15
#
# Rule: If a person buys 30000 and 110000 they will also buy 130000
#  - Confidence: 0.043
#  - Support: 21
#
# Rule: If a person buys 80000 and 130000 they will also buy 120000
#  - Confidence: 0.045
#  - Support: 16
#
# Rule: If a person buys 170000 and 20000 they will also buy 110000
#  - Confidence: 0.059
#  - Support: 11
#
# Rule: If a person buys 170000 and 120000 they will also buy 130000
#  - Confidence: 0.039
#  - Support: 8
#
# Rule: If a person buys 50000 and 160000 they will also buy 70000
#  - Confidence: 0.055
#  - Support: 15
#
# Rule: If a person buys 80000 and 130000 they will also buy 200000
#  - Confidence: 0.045
#  - Support: 16
#
# Rule: If a person buys 180000 and 90000 they will also buy 190000
#  - Confidence: 0.051
#  - Support: 7
#
# Rule: If a person buys 150000 and 130000 they will also buy 60000
#  - Confidence: 0.048
#  - Support: 9
#
# Rule: If a person buys 120000 and 140000 they will also buy 110000
#  - Confidence: 0.059
#  - Support: 10
#
# Rule: If a person buys 80000 and 120000 they will also buy 30000
#  - Confidence: 0.053
#  - Support: 20
#
# Rule: If a person buys 20000 and 180000 they will also buy 80000
#  - Confidence: 0.059
#  - Support: 7
#
# Rule: If a person buys 190000 and 70000 they will also buy 80000
#  - Confidence: 0.048
#  - Support: 18
#
# Rule: If a person buys 120000 and 110000 they will also buy 200000
#  - Confidence: 0.039
#  - Support: 14
#
# Rule: If a person buys 130000 and 70000 they will also buy 200000
#  - Confidence: 0.043
#  - Support: 17
#
# Rule: If a person buys 180000 and 140000 they will also buy 120000
#  - Confidence: 0.047
#  - Support: 4
#
# Rule: If a person buys 110000 and 60000 they will also buy 70000
#  - Confidence: 0.057
#  - Support: 26
#
# Rule: If a person buys 150000 and 120000 they will also buy 20000
#  - Confidence: 0.054
#  - Support: 12
#
# Rule: If a person buys 90000 and 30000 they will also buy 170000
#  - Confidence: 0.024
#  - Support: 13
#
# Rule: If a person buys 20000 and 100000 they will also buy 170000
#  - Confidence: 0.025
#  - Support: 9
#
# Rule: If a person buys 100000 and 70000 they will also buy 130000
#  - Confidence: 0.039
#  - Support: 18
#
# Rule: If a person buys 40000 and 160000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 15
#
# Rule: If a person buys 160000 and 130000 they will also buy 180000
#  - Confidence: 0.029
#  - Support: 7
#
# Rule: If a person buys 30000 and 40000 they will also buy 180000
#  - Confidence: 0.015
#  - Support: 8
#
# Rule: If a person buys 160000 and 130000 they will also buy 190000
#  - Confidence: 0.046
#  - Support: 11
#
# Rule: If a person buys 90000 and 50000 they will also buy 200000
#  - Confidence: 0.041
#  - Support: 21
#
# Rule: If a person buys 60000 and 170000 they will also buy 120000
#  - Confidence: 0.050
#  - Support: 12
#
# Rule: If a person buys 50000 and 140000 they will also buy 170000
#  - Confidence: 0.023
#  - Support: 5
#
# Rule: If a person buys 150000 and 110000 they will also buy 50000
#  - Confidence: 0.059
#  - Support: 14
#
# Rule: If a person buys 160000 and 120000 they will also buy 200000
#  - Confidence: 0.054
#  - Support: 11
#
# Rule: If a person buys 30000 and 100000 they will also buy 150000
#  - Confidence: 0.025
#  - Support: 12
#
# Rule: If a person buys 70000 and 130000 they will also buy 200000
#  - Confidence: 0.043
#  - Support: 17
#
# Rule: If a person buys 20000 and 100000 they will also buy 190000
#  - Confidence: 0.045
#  - Support: 16
#
# Rule: If a person buys 30000 and 160000 they will also buy 170000
#  - Confidence: 0.031
#  - Support: 8
#
# Rule: If a person buys 200000 and 50000 they will also buy 20000
#  - Confidence: 0.045
#  - Support: 17
#
# Rule: If a person buys 170000 and 20000 they will also buy 60000
#  - Confidence: 0.053
#  - Support: 10
#
# Rule: If a person buys 180000 and 40000 they will also buy 200000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 160000 and 200000 they will also buy 80000
#  - Confidence: 0.051
#  - Support: 14
#
# Rule: If a person buys 170000 and 90000 they will also buy 120000
#  - Confidence: 0.046
#  - Support: 11
#
# Rule: If a person buys 190000 and 200000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 16
#
# Rule: If a person buys 130000 and 90000 they will also buy 180000
#  - Confidence: 0.024
#  - Support: 8
#
# Rule: If a person buys 130000 and 60000 they will also buy 120000
#  - Confidence: 0.046
#  - Support: 15
#
# Rule: If a person buys 190000 and 170000 they will also buy 100000
#  - Confidence: 0.044
#  - Support: 6
#
# Rule: If a person buys 70000 and 190000 they will also buy 150000
#  - Confidence: 0.027
#  - Support: 10
#
# Rule: If a person buys 150000 and 170000 they will also buy 90000
#  - Confidence: 0.052
#  - Support: 8
#
# Rule: If a person buys 200000 and 110000 they will also buy 130000
#  - Confidence: 0.043
#  - Support: 17
#
# Rule: If a person buys 190000 and 60000 they will also buy 100000
#  - Confidence: 0.049
#  - Support: 15
#
# Rule: If a person buys 180000 and 140000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 5
#
# Rule: If a person buys 130000 and 100000 they will also buy 160000
#  - Confidence: 0.046
#  - Support: 14
#
# Rule: If a person buys 190000 and 110000 they will also buy 100000
#  - Confidence: 0.050
#  - Support: 17
#
# Rule: If a person buys 40000 and 60000 they will also buy 150000
#  - Confidence: 0.024
#  - Support: 12
#
# Rule: If a person buys 60000 and 70000 they will also buy 40000
#  - Confidence: 0.055
#  - Support: 28
#
# Rule: If a person buys 60000 and 50000 they will also buy 20000
#  - Confidence: 0.044
#  - Support: 21
#
# Rule: If a person buys 190000 and 30000 they will also buy 140000
#  - Confidence: 0.037
#  - Support: 12
#
# Rule: If a person buys 200000 and 120000 they will also buy 80000
#  - Confidence: 0.055
#  - Support: 16
#
# Rule: If a person buys 120000 and 170000 they will also buy 110000
#  - Confidence: 0.054
#  - Support: 11
#
# Rule: If a person buys 50000 and 140000 they will also buy 60000
#  - Confidence: 0.054
#  - Support: 12
#
# Rule: If a person buys 30000 and 170000 they will also buy 90000
#  - Confidence: 0.051
#  - Support: 13
#
# Rule: If a person buys 60000 and 40000 they will also buy 20000
#  - Confidence: 0.045
#  - Support: 22
#
# Rule: If a person buys 40000 and 60000 they will also buy 50000
#  - Confidence: 0.053
#  - Support: 26
#
# Rule: If a person buys 50000 and 60000 they will also buy 130000
#  - Confidence: 0.038
#  - Support: 18
#
# Rule: If a person buys 80000 and 140000 they will also buy 170000
#  - Confidence: 0.023
#  - Support: 5
#
# Rule: If a person buys 80000 and 160000 they will also buy 50000
#  - Confidence: 0.059
#  - Support: 15
#
# Rule: If a person buys 80000 and 190000 they will also buy 50000
#  - Confidence: 0.052
#  - Support: 16
#
# Rule: If a person buys 160000 and 20000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 14
#
# Rule: If a person buys 60000 and 140000 they will also buy 170000
#  - Confidence: 0.023
#  - Support: 5
#
# Rule: If a person buys 160000 and 130000 they will also buy 200000
#  - Confidence: 0.055
#  - Support: 13
#
# Rule: If a person buys 180000 and 70000 they will also buy 190000
#  - Confidence: 0.046
#  - Support: 7
#
# Rule: If a person buys 200000 and 180000 they will also buy 100000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 20000 and 150000 they will also buy 80000
#  - Confidence: 0.054
#  - Support: 12
#
# Rule: If a person buys 100000 and 200000 they will also buy 150000
#  - Confidence: 0.027
#  - Support: 10
#
# Rule: If a person buys 180000 and 20000 they will also buy 110000
#  - Confidence: 0.059
#  - Support: 7
#
# Rule: If a person buys 190000 and 150000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 10
#
# Rule: If a person buys 150000 and 120000 they will also buy 160000
#  - Confidence: 0.045
#  - Support: 10
#
# Rule: If a person buys 80000 and 170000 they will also buy 180000
#  - Confidence: 0.014
#  - Support: 3
#
# Rule: If a person buys 100000 and 120000 they will also buy 140000
#  - Confidence: 0.029
#  - Support: 10
#
# Rule: If a person buys 180000 and 150000 they will also buy 80000
#  - Confidence: 0.042
#  - Support: 5
#
# Rule: If a person buys 60000 and 20000 they will also buy 100000
#  - Confidence: 0.051
#  - Support: 19
#
# Rule: If a person buys 110000 and 80000 they will also buy 180000
#  - Confidence: 0.017
#  - Support: 8
#
# Rule: If a person buys 30000 and 80000 they will also buy 170000
#  - Confidence: 0.024
#  - Support: 12
#
# Rule: If a person buys 180000 and 110000 they will also buy 190000
#  - Confidence: 0.046
#  - Support: 7
#
# Rule: If a person buys 150000 and 170000 they will also buy 50000
#  - Confidence: 0.059
#  - Support: 9
#
# Rule: If a person buys 160000 and 100000 they will also buy 140000
#  - Confidence: 0.033
#  - Support: 9
#
# Rule: If a person buys 30000 and 120000 they will also buy 100000
#  - Confidence: 0.047
#  - Support: 20
#
# Rule: If a person buys 120000 and 150000 they will also buy 200000
#  - Confidence: 0.045
#  - Support: 10
#
# Rule: If a person buys 160000 and 140000 they will also buy 60000
#  - Confidence: 0.059
#  - Support: 9
#
# Rule: If a person buys 20000 and 40000 they will also buy 150000
#  - Confidence: 0.027
#  - Support: 12
#
# Rule: If a person buys 120000 and 100000 they will also buy 190000
#  - Confidence: 0.035
#  - Support: 12
#
# Rule: If a person buys 160000 and 100000 they will also buy 90000
#  - Confidence: 0.059
#  - Support: 16
#
# Rule: If a person buys 70000 and 150000 they will also buy 200000
#  - Confidence: 0.035
#  - Support: 10
#
# Rule: If a person buys 40000 and 200000 they will also buy 30000
#  - Confidence: 0.056
#  - Support: 22
#
# Rule: If a person buys 70000 and 80000 they will also buy 100000
#  - Confidence: 0.039
#  - Support: 22
#
# Rule: If a person buys 60000 and 110000 they will also buy 160000
#  - Confidence: 0.031
#  - Support: 14
#
# Rule: If a person buys 90000 and 120000 they will also buy 160000
#  - Confidence: 0.031
#  - Support: 12
#
# Rule: If a person buys 100000 and 60000 they will also buy 20000
#  - Confidence: 0.041
#  - Support: 19
#
# Rule: If a person buys 80000 and 50000 they will also buy 170000
#  - Confidence: 0.024
#  - Support: 12
#
# Rule: If a person buys 190000 and 120000 they will also buy 160000
#  - Confidence: 0.039
#  - Support: 10
#
# Rule: If a person buys 120000 and 180000 they will also buy 20000
#  - Confidence: 0.050
#  - Support: 6
#
# Rule: If a person buys 110000 and 150000 they will also buy 30000
#  - Confidence: 0.055
#  - Support: 13
#
# Rule: If a person buys 40000 and 110000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 29
#
# Rule: If a person buys 140000 and 170000 they will also buy 40000
#  - Confidence: 0.059
#  - Support: 5
#
# Rule: If a person buys 150000 and 70000 they will also buy 140000
#  - Confidence: 0.028
#  - Support: 8
#
# Rule: If a person buys 90000 and 150000 they will also buy 60000
#  - Confidence: 0.047
#  - Support: 12
#
# Rule: If a person buys 90000 and 100000 they will also buy 140000
#  - Confidence: 0.029
#  - Support: 13
#
# Rule: If a person buys 160000 and 200000 they will also buy 110000
#  - Confidence: 0.051
#  - Support: 14
#
# Rule: If a person buys 190000 and 120000 they will also buy 60000
#  - Confidence: 0.051
#  - Support: 13
#
# Rule: If a person buys 120000 and 30000 they will also buy 20000
#  - Confidence: 0.038
#  - Support: 16
#
# Rule: If a person buys 180000 and 80000 they will also buy 40000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 70000 and 80000 they will also buy 200000
#  - Confidence: 0.037
#  - Support: 21
#
# Rule: If a person buys 80000 and 50000 they will also buy 130000
#  - Confidence: 0.039
#  - Support: 20
#
# Rule: If a person buys 80000 and 60000 they will also buy 130000
#  - Confidence: 0.040
#  - Support: 19
#
# Rule: If a person buys 70000 and 160000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 15
#
# Rule: If a person buys 60000 and 80000 they will also buy 120000
#  - Confidence: 0.040
#  - Support: 19
#
# Rule: If a person buys 150000 and 80000 they will also buy 200000
#  - Confidence: 0.039
#  - Support: 10
#
# Rule: If a person buys 140000 and 100000 they will also buy 20000
#  - Confidence: 0.050
#  - Support: 12
#
# Rule: If a person buys 120000 and 80000 they will also buy 60000
#  - Confidence: 0.051
#  - Support: 19
#
# Rule: If a person buys 200000 and 70000 they will also buy 120000
#  - Confidence: 0.035
#  - Support: 15
#
# Rule: If a person buys 180000 and 170000 they will also buy 50000
#  - Confidence: 0.059
#  - Support: 4
#
# Rule: If a person buys 130000 and 20000 they will also buy 60000
#  - Confidence: 0.050
#  - Support: 17
#
# Rule: If a person buys 60000 and 100000 they will also buy 160000
#  - Confidence: 0.035
#  - Support: 16
#
# Rule: If a person buys 160000 and 110000 they will also buy 100000
#  - Confidence: 0.055
#  - Support: 14
#
# Rule: If a person buys 180000 and 20000 they will also buy 170000
#  - Confidence: 0.025
#  - Support: 3
#
# Rule: If a person buys 90000 and 100000 they will also buy 40000
#  - Confidence: 0.052
#  - Support: 23
#
# Rule: If a person buys 60000 and 80000 they will also buy 90000
#  - Confidence: 0.053
#  - Support: 25
#
# Rule: If a person buys 30000 and 20000 they will also buy 140000
#  - Confidence: 0.031
#  - Support: 13
#
# Rule: If a person buys 90000 and 40000 they will also buy 80000
#  - Confidence: 0.051
#  - Support: 27
#
# Rule: If a person buys 190000 and 90000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 18
#
# Rule: If a person buys 200000 and 90000 they will also buy 160000
#  - Confidence: 0.038
#  - Support: 15
#
# Rule: If a person buys 60000 and 190000 they will also buy 200000
#  - Confidence: 0.042
#  - Support: 13
#
# Rule: If a person buys 180000 and 70000 they will also buy 60000
#  - Confidence: 0.052
#  - Support: 8
#
# Rule: If a person buys 190000 and 20000 they will also buy 120000
#  - Confidence: 0.040
#  - Support: 13
#
# Rule: If a person buys 100000 and 80000 they will also buy 150000
#  - Confidence: 0.029
#  - Support: 12
#
# Rule: If a person buys 190000 and 20000 they will also buy 170000
#  - Confidence: 0.025
#  - Support: 8
#
# Rule: If a person buys 170000 and 80000 they will also buy 120000
#  - Confidence: 0.054
#  - Support: 12
#
# Rule: If a person buys 60000 and 90000 they will also buy 50000
#  - Confidence: 0.057
#  - Support: 27
#
# Rule: If a person buys 70000 and 170000 they will also buy 80000
#  - Confidence: 0.050
#  - Support: 12
#
# Rule: If a person buys 110000 and 200000 they will also buy 190000
#  - Confidence: 0.038
#  - Support: 15
#
# Rule: If a person buys 150000 and 40000 they will also buy 110000
#  - Confidence: 0.051
#  - Support: 13
#
# Rule: If a person buys 30000 and 130000 they will also buy 40000
#  - Confidence: 0.053
#  - Support: 20
#
# Rule: If a person buys 110000 and 90000 they will also buy 20000
#  - Confidence: 0.048
#  - Support: 23
#
# Rule: If a person buys 190000 and 170000 they will also buy 30000
#  - Confidence: 0.051
#  - Support: 7
#
# Rule: If a person buys 170000 and 130000 they will also buy 40000
#  - Confidence: 0.048
#  - Support: 9
#
# Rule: If a person buys 50000 and 90000 they will also buy 200000
#  - Confidence: 0.041
#  - Support: 21
#
# Rule: If a person buys 150000 and 60000 they will also buy 140000
#  - Confidence: 0.034
#  - Support: 8
#
# Rule: If a person buys 30000 and 20000 they will also buy 80000
#  - Confidence: 0.054
#  - Support: 23
#
# Rule: If a person buys 50000 and 110000 they will also buy 180000
#  - Confidence: 0.019
#  - Support: 9
#
# Rule: If a person buys 180000 and 20000 they will also buy 100000
#  - Confidence: 0.059
#  - Support: 7
#
# Rule: If a person buys 200000 and 130000 they will also buy 160000
#  - Confidence: 0.045
#  - Support: 13
#
# Rule: If a person buys 200000 and 130000 they will also buy 100000
#  - Confidence: 0.052
#  - Support: 15
#
# Rule: If a person buys 150000 and 30000 they will also buy 40000
#  - Confidence: 0.055
#  - Support: 14
#
# Rule: If a person buys 200000 and 140000 they will also buy 20000
#  - Confidence: 0.059
#  - Support: 10
#
# Rule: If a person buys 90000 and 30000 they will also buy 180000
#  - Confidence: 0.015
#  - Support: 8
#
# Rule: If a person buys 70000 and 40000 they will also buy 140000
#  - Confidence: 0.024
#  - Support: 14
#
# Rule: If a person buys 70000 and 80000 they will also buy 90000
#  - Confidence: 0.048
#  - Support: 27
#
# Rule: If a person buys 100000 and 140000 they will also buy 90000
#  - Confidence: 0.055
#  - Support: 13
#
# Rule: If a person buys 80000 and 140000 they will also buy 180000
#  - Confidence: 0.023
#  - Support: 5
#
# Rule: If a person buys 140000 and 110000 they will also buy 160000
#  - Confidence: 0.041
#  - Support: 9
#
# Rule: If a person buys 80000 and 110000 they will also buy 160000
#  - Confidence: 0.031
#  - Support: 14
#
# Rule: If a person buys 130000 and 110000 they will also buy 120000
#  - Confidence: 0.043
#  - Support: 16
#
# Rule: If a person buys 90000 and 100000 they will also buy 80000
#  - Confidence: 0.050
#  - Support: 22
#
# Rule: If a person buys 160000 and 150000 they will also buy 40000
#  - Confidence: 0.059
#  - Support: 10
#
# Rule: If a person buys 170000 and 140000 they will also buy 200000
#  - Confidence: 0.047
#  - Support: 4
#
# Rule: If a person buys 80000 and 130000 they will also buy 100000
#  - Confidence: 0.050
#  - Support: 18
#
# Rule: If a person buys 110000 and 60000 they will also buy 30000
#  - Confidence: 0.052
#  - Support: 24
#
# Rule: If a person buys 60000 and 70000 they will also buy 200000
#  - Confidence: 0.039
#  - Support: 20
#
# Rule: If a person buys 50000 and 60000 they will also buy 40000
#  - Confidence: 0.055
#  - Support: 26
#
# Rule: If a person buys 60000 and 110000 they will also buy 150000
#  - Confidence: 0.024
#  - Support: 11
#
# Rule: If a person buys 180000 and 80000 they will also buy 150000
#  - Confidence: 0.037
#  - Support: 5
#
# Rule: If a person buys 40000 and 20000 they will also buy 150000
#  - Confidence: 0.027
#  - Support: 12
#
# Rule: If a person buys 120000 and 30000 they will also buy 170000
#  - Confidence: 0.026
#  - Support: 11
#
# Rule: If a person buys 120000 and 180000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 7
#
# Rule: If a person buys 160000 and 40000 they will also buy 60000
#  - Confidence: 0.059
#  - Support: 15
#
# Rule: If a person buys 110000 and 40000 they will also buy 100000
#  - Confidence: 0.049
#  - Support: 24
#
# Rule: If a person buys 200000 and 60000 they will also buy 50000
#  - Confidence: 0.056
#  - Support: 22
#
# Rule: If a person buys 180000 and 80000 they will also buy 20000
#  - Confidence: 0.051
#  - Support: 7
#
# Rule: If a person buys 160000 and 50000 they will also buy 130000
#  - Confidence: 0.051
#  - Support: 14
#
# Rule: If a person buys 120000 and 170000 they will also buy 90000
#  - Confidence: 0.054
#  - Support: 11
#
# Rule: If a person buys 60000 and 30000 they will also buy 80000
#  - Confidence: 0.051
#  - Support: 25
#
# Rule: If a person buys 40000 and 80000 they will also buy 50000
#  - Confidence: 0.055
#  - Support: 29
#
# Rule: If a person buys 30000 and 160000 they will also buy 80000
#  - Confidence: 0.059
#  - Support: 15
#
# Rule: If a person buys 120000 and 180000 they will also buy 170000
#  - Confidence: 0.025
#  - Support: 3
#
# Rule: If a person buys 140000 and 80000 they will also buy 160000
#  - Confidence: 0.041
#  - Support: 9
#
# Rule: If a person buys 20000 and 150000 they will also buy 130000
#  - Confidence: 0.045
#  - Support: 10
#
# Rule: If a person buys 90000 and 80000 they will also buy 180000
#  - Confidence: 0.017
#  - Support: 8
#
# Rule: If a person buys 190000 and 70000 they will also buy 30000
#  - Confidence: 0.051
#  - Support: 19
#
# Rule: If a person buys 170000 and 180000 they will also buy 40000
#  - Confidence: 0.044
#  - Support: 3
#
# Rule: If a person buys 200000 and 180000 they will also buy 140000
#  - Confidence: 0.037
#  - Support: 5
#
# Rule: If a person buys 60000 and 170000 they will also buy 150000
#  - Confidence: 0.034
#  - Support: 8
#
# Rule: If a person buys 50000 and 70000 they will also buy 40000
#  - Confidence: 0.055
#  - Support: 30
#
# Rule: If a person buys 100000 and 30000 they will also buy 80000
#  - Confidence: 0.050
#  - Support: 24
#
# Rule: If a person buys 70000 and 170000 they will also buy 180000
#  - Confidence: 0.017
#  - Support: 4
#
# Rule: If a person buys 30000 and 120000 they will also buy 90000
#  - Confidence: 0.054
#  - Support: 23
#
# Rule: If a person buys 40000 and 70000 they will also buy 50000
#  - Confidence: 0.052
#  - Support: 30
#
# Rule: If a person buys 100000 and 40000 they will also buy 60000
#  - Confidence: 0.054
#  - Support: 23
#
# Rule: If a person buys 200000 and 20000 they will also buy 100000
#  - Confidence: 0.053
#  - Support: 17
#
# Rule: If a person buys 20000 and 70000 they will also buy 60000
#  - Confidence: 0.048
#  - Support: 22
#
# Rule: If a person buys 80000 and 180000 they will also buy 200000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 30000 and 70000 they will also buy 50000
#  - Confidence: 0.050
#  - Support: 29
#
# Rule: If a person buys 180000 and 120000 they will also buy 170000
#  - Confidence: 0.025
#  - Support: 3
#
# Rule: If a person buys 110000 and 60000 they will also buy 20000
#  - Confidence: 0.046
#  - Support: 21
#
# Rule: If a person buys 200000 and 50000 they will also buy 190000
#  - Confidence: 0.035
#  - Support: 13
#
# Rule: If a person buys 170000 and 90000 they will also buy 110000
#  - Confidence: 0.050
#  - Support: 12
#
# Rule: If a person buys 50000 and 170000 they will also buy 140000
#  - Confidence: 0.023
#  - Support: 5
#
# Rule: If a person buys 100000 and 110000 they will also buy 160000
#  - Confidence: 0.033
#  - Support: 14
#
# Rule: If a person buys 60000 and 100000 they will also buy 150000
#  - Confidence: 0.024
#  - Support: 11
#
# Rule: If a person buys 40000 and 140000 they will also buy 130000
#  - Confidence: 0.046
#  - Support: 11
#
# Rule: If a person buys 20000 and 170000 they will also buy 30000
#  - Confidence: 0.053
#  - Support: 10
#
# Rule: If a person buys 170000 and 30000 they will also buy 90000
#  - Confidence: 0.051
#  - Support: 13
#
# Rule: If a person buys 140000 and 160000 they will also buy 180000
#  - Confidence: 0.033
#  - Support: 5
#
# Rule: If a person buys 200000 and 190000 they will also buy 160000
#  - Confidence: 0.037
#  - Support: 10
#
# Rule: If a person buys 160000 and 50000 they will also buy 140000
#  - Confidence: 0.033
#  - Support: 9
#
# Rule: If a person buys 140000 and 70000 they will also buy 40000
#  - Confidence: 0.059
#  - Support: 14
#
# Rule: If a person buys 110000 and 50000 they will also buy 120000
#  - Confidence: 0.042
#  - Support: 20
#
# Rule: If a person buys 80000 and 190000 they will also buy 180000
#  - Confidence: 0.023
#  - Support: 7
#
# Rule: If a person buys 110000 and 180000 they will also buy 100000
#  - Confidence: 0.052
#  - Support: 8
#
# Rule: If a person buys 40000 and 200000 they will also buy 100000
#  - Confidence: 0.049
#  - Support: 19
#
# Rule: If a person buys 110000 and 140000 they will also buy 130000
#  - Confidence: 0.045
#  - Support: 10
#
# Rule: If a person buys 180000 and 100000 they will also buy 90000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 140000 and 150000 they will also buy 110000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 90000 and 80000 they will also buy 50000
#  - Confidence: 0.059
#  - Support: 28
#
# Rule: If a person buys 20000 and 60000 they will also buy 130000
#  - Confidence: 0.045
#  - Support: 17
#
# Rule: If a person buys 150000 and 90000 they will also buy 60000
#  - Confidence: 0.047
#  - Support: 12
#
# Rule: If a person buys 80000 and 90000 they will also buy 30000
#  - Confidence: 0.055
#  - Support: 26
#
# Rule: If a person buys 200000 and 180000 they will also buy 190000
#  - Confidence: 0.051
#  - Support: 7
#
# Rule: If a person buys 200000 and 90000 they will also buy 80000
#  - Confidence: 0.051
#  - Support: 20
#
# Rule: If a person buys 70000 and 150000 they will also buy 120000
#  - Confidence: 0.045
#  - Support: 13
#
# Rule: If a person buys 40000 and 190000 they will also buy 140000
#  - Confidence: 0.035
#  - Support: 12
#
# Rule: If a person buys 140000 and 190000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 12
#
# Rule: If a person buys 130000 and 40000 they will also buy 180000
#  - Confidence: 0.022
#  - Support: 8
#
# Rule: If a person buys 60000 and 110000 they will also buy 90000
#  - Confidence: 0.052
#  - Support: 24
#
# Rule: If a person buys 70000 and 160000 they will also buy 150000
#  - Confidence: 0.039
#  - Support: 10
#
# Rule: If a person buys 90000 and 50000 they will also buy 20000
#  - Confidence: 0.043
#  - Support: 22
#
# Rule: If a person buys 100000 and 70000 they will also buy 150000
#  - Confidence: 0.026
#  - Support: 12
#
# Rule: If a person buys 70000 and 90000 they will also buy 140000
#  - Confidence: 0.024
#  - Support: 13
#
# Rule: If a person buys 80000 and 200000 they will also buy 130000
#  - Confidence: 0.043
#  - Support: 16
#
# Rule: If a person buys 130000 and 170000 they will also buy 110000
#  - Confidence: 0.059
#  - Support: 11
#
# Rule: If a person buys 90000 and 70000 they will also buy 130000
#  - Confidence: 0.035
#  - Support: 19
#
# Rule: If a person buys 140000 and 60000 they will also buy 130000
#  - Confidence: 0.045
#  - Support: 10
#
# Rule: If a person buys 140000 and 170000 they will also buy 150000
#  - Confidence: 0.059
#  - Support: 5
#
# Rule: If a person buys 60000 and 80000 they will also buy 180000
#  - Confidence: 0.017
#  - Support: 8
#
# Rule: If a person buys 180000 and 60000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 190000 and 40000 they will also buy 170000
#  - Confidence: 0.021
#  - Support: 7
#
# Rule: If a person buys 90000 and 120000 they will also buy 130000
#  - Confidence: 0.038
#  - Support: 15
#
# Rule: If a person buys 180000 and 150000 they will also buy 60000
#  - Confidence: 0.042
#  - Support: 5
#
# Rule: If a person buys 180000 and 60000 they will also buy 110000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 90000 and 190000 they will also buy 130000
#  - Confidence: 0.046
#  - Support: 14
#
# Rule: If a person buys 170000 and 190000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 110000 and 60000 they will also buy 150000
#  - Confidence: 0.024
#  - Support: 11
#
# Rule: If a person buys 100000 and 80000 they will also buy 190000
#  - Confidence: 0.037
#  - Support: 15
#
# Rule: If a person buys 160000 and 50000 they will also buy 150000
#  - Confidence: 0.037
#  - Support: 10
#
# Rule: If a person buys 150000 and 50000 they will also buy 40000
#  - Confidence: 0.055
#  - Support: 15
#
# Rule: If a person buys 110000 and 60000 they will also buy 180000
#  - Confidence: 0.017
#  - Support: 8
#
# Rule: If a person buys 160000 and 70000 they will also buy 180000
#  - Confidence: 0.027
#  - Support: 7
#
# Rule: If a person buys 80000 and 170000 they will also buy 130000
#  - Confidence: 0.041
#  - Support: 9
#
# Rule: If a person buys 110000 and 90000 they will also buy 70000
#  - Confidence: 0.057
#  - Support: 27
#
# Rule: If a person buys 70000 and 140000 they will also buy 80000
#  - Confidence: 0.050
#  - Support: 12
#
# Rule: If a person buys 40000 and 200000 they will also buy 180000
#  - Confidence: 0.020
#  - Support: 8
#
# Rule: If a person buys 200000 and 100000 they will also buy 20000
#  - Confidence: 0.045
#  - Support: 17
#
# Rule: If a person buys 190000 and 140000 they will also buy 200000
#  - Confidence: 0.049
#  - Support: 10
#
# Rule: If a person buys 80000 and 130000 they will also buy 20000
#  - Confidence: 0.053
#  - Support: 19
#
# Rule: If a person buys 120000 and 160000 they will also buy 60000
#  - Confidence: 0.059
#  - Support: 12
#
# Rule: If a person buys 150000 and 180000 they will also buy 70000
#  - Confidence: 0.050
#  - Support: 6
#
# Rule: If a person buys 150000 and 50000 they will also buy 60000
#  - Confidence: 0.044
#  - Support: 12
#
# Rule: If a person buys 170000 and 140000 they will also buy 120000
#  - Confidence: 0.059
#  - Support: 5
#
# Rule: If a person buys 170000 and 30000 they will also buy 150000
#  - Confidence: 0.035
#  - Support: 9
#
# Rule: If a person buys 50000 and 20000 they will also buy 130000
#  - Confidence: 0.044
#  - Support: 18
#
# Rule: If a person buys 60000 and 150000 they will also buy 90000
#  - Confidence: 0.050
#  - Support: 12
#
# Rule: If a person buys 170000 and 130000 they will also buy 160000
#  - Confidence: 0.037
#  - Support: 7
#
# Rule: If a person buys 20000 and 190000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 19
#
# Rule: If a person buys 100000 and 30000 they will also buy 40000
#  - Confidence: 0.050
#  - Support: 24
#
# Rule: If a person buys 90000 and 20000 they will also buy 50000
#  - Confidence: 0.054
#  - Support: 22
#
# Rule: If a person buys 150000 and 190000 they will also buy 110000
#  - Confidence: 0.059
#  - Support: 10
#
# Rule: If a person buys 180000 and 30000 they will also buy 70000
#  - Confidence: 0.053
#  - Support: 9
#
# Rule: If a person buys 110000 and 80000 they will also buy 60000
#  - Confidence: 0.054
#  - Support: 25
#
# Rule: If a person buys 110000 and 100000 they will also buy 140000
#  - Confidence: 0.031
#  - Support: 13
#
# Rule: If a person buys 130000 and 90000 they will also buy 160000
#  - Confidence: 0.041
#  - Support: 14
#
# Rule: If a person buys 180000 and 100000 they will also buy 170000
#  - Confidence: 0.022
#  - Support: 3
#
# Rule: If a person buys 100000 and 140000 they will also buy 170000
#  - Confidence: 0.021
#  - Support: 5
#
# Rule: If a person buys 140000 and 60000 they will also buy 120000
#  - Confidence: 0.045
#  - Support: 10
#
# Rule: If a person buys 170000 and 80000 they will also buy 150000
#  - Confidence: 0.036
#  - Support: 8
#
# Rule: If a person buys 190000 and 40000 they will also buy 110000
#  - Confidence: 0.056
#  - Support: 19
#
# Rule: If a person buys 120000 and 130000 they will also buy 180000
#  - Confidence: 0.026
#  - Support: 7
#
# Rule: If a person buys 120000 and 200000 they will also buy 130000
#  - Confidence: 0.042
#  - Support: 12
#
# Rule: If a person buys 140000 and 100000 they will also buy 90000
#  - Confidence: 0.055
#  - Support: 13
#
# Rule: If a person buys 180000 and 70000 they will also buy 170000
#  - Confidence: 0.026
#  - Support: 4
#
# Rule: If a person buys 30000 and 150000 they will also buy 120000
#  - Confidence: 0.051
#  - Support: 13
#
# Rule: If a person buys 70000 and 80000 they will also buy 150000
#  - Confidence: 0.027
#  - Support: 15
#
# Rule: If a person buys 180000 and 100000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 180000 and 40000 they will also buy 50000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 150000 and 130000 they will also buy 160000
#  - Confidence: 0.048
#  - Support: 9
#
# Rule: If a person buys 170000 and 110000 they will also buy 30000
#  - Confidence: 0.055
#  - Support: 13
#
# Rule: If a person buys 30000 and 140000 they will also buy 90000
#  - Confidence: 0.051
#  - Support: 13
#
# Rule: If a person buys 100000 and 120000 they will also buy 60000
#  - Confidence: 0.053
#  - Support: 18
#
# Rule: If a person buys 130000 and 110000 they will also buy 170000
#  - Confidence: 0.029
#  - Support: 11
#
# Rule: If a person buys 120000 and 100000 they will also buy 170000
#  - Confidence: 0.029
#  - Support: 10
#
# Rule: If a person buys 70000 and 90000 they will also buy 60000
#  - Confidence: 0.048
#  - Support: 26
#
# Rule: If a person buys 200000 and 120000 they will also buy 130000
#  - Confidence: 0.042
#  - Support: 12
#
# Rule: If a person buys 150000 and 90000 they will also buy 130000
#  - Confidence: 0.039
#  - Support: 10
#
# Rule: If a person buys 180000 and 40000 they will also buy 130000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 20000 and 40000 they will also buy 100000
#  - Confidence: 0.048
#  - Support: 21
#
# Rule: If a person buys 180000 and 80000 they will also buy 200000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 40000 and 100000 they will also buy 140000
#  - Confidence: 0.031
#  - Support: 13
#
# Rule: If a person buys 100000 and 20000 they will also buy 190000
#  - Confidence: 0.045
#  - Support: 16
#
# Rule: If a person buys 180000 and 80000 they will also buy 60000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 190000 and 180000 they will also buy 60000
#  - Confidence: 0.059
#  - Support: 7
#
# Rule: If a person buys 40000 and 170000 they will also buy 130000
#  - Confidence: 0.041
#  - Support: 9
#
# Rule: If a person buys 50000 and 120000 they will also buy 110000
#  - Confidence: 0.056
#  - Support: 20
#
# Rule: If a person buys 90000 and 150000 they will also buy 160000
#  - Confidence: 0.039
#  - Support: 10
#
# Rule: If a person buys 150000 and 80000 they will also buy 190000
#  - Confidence: 0.039
#  - Support: 10
#
# Rule: If a person buys 40000 and 70000 they will also buy 30000
#  - Confidence: 0.050
#  - Support: 29
#
# Rule: If a person buys 200000 and 120000 they will also buy 170000
#  - Confidence: 0.031
#  - Support: 9
#
# Rule: If a person buys 170000 and 60000 they will also buy 160000
#  - Confidence: 0.034
#  - Support: 8
#
# Rule: If a person buys 120000 and 40000 they will also buy 80000
#  - Confidence: 0.054
#  - Support: 21
#
# Rule: If a person buys 50000 and 60000 they will also buy 200000
#  - Confidence: 0.046
#  - Support: 22
#
# Rule: If a person buys 180000 and 140000 they will also buy 130000
#  - Confidence: 0.059
#  - Support: 5
#
# Rule: If a person buys 110000 and 140000 they will also buy 90000
#  - Confidence: 0.059
#  - Support: 13
#
# Rule: If a person buys 70000 and 170000 they will also buy 140000
#  - Confidence: 0.021
#  - Support: 5
#
# Rule: If a person buys 150000 and 50000 they will also buy 160000
#  - Confidence: 0.037
#  - Support: 10
#
# Rule: If a person buys 190000 and 70000 they will also buy 180000
#  - Confidence: 0.019
#  - Support: 7
#
# Rule: If a person buys 40000 and 70000 they will also buy 170000
#  - Confidence: 0.021
#  - Support: 12
#
# Rule: If a person buys 100000 and 60000 they will also buy 70000
#  - Confidence: 0.050
#  - Support: 23
#
# Rule: If a person buys 180000 and 170000 they will also buy 130000
#  - Confidence: 0.059
#  - Support: 4
#
# Rule: If a person buys 170000 and 100000 they will also buy 140000
#  - Confidence: 0.025
#  - Support: 5
#
# Rule: If a person buys 200000 and 130000 they will also buy 110000
#  - Confidence: 0.059
#  - Support: 17
#
# Rule: If a person buys 90000 and 120000 they will also buy 40000
#  - Confidence: 0.051
#  - Support: 20
#
# Rule: If a person buys 60000 and 120000 they will also buy 190000
#  - Confidence: 0.035
#  - Support: 13
#
# Rule: If a person buys 60000 and 110000 they will also buy 170000
#  - Confidence: 0.026
#  - Support: 12
#
# Rule: If a person buys 140000 and 120000 they will also buy 170000
#  - Confidence: 0.029
#  - Support: 5
#
# Rule: If a person buys 110000 and 120000 they will also buy 90000
#  - Confidence: 0.056
#  - Support: 20
#
# Rule: If a person buys 90000 and 30000 they will also buy 110000
#  - Confidence: 0.050
#  - Support: 27
#
# Rule: If a person buys 120000 and 70000 they will also buy 150000
#  - Confidence: 0.032
#  - Support: 13
#
# Rule: If a person buys 40000 and 100000 they will also buy 130000
#  - Confidence: 0.042
#  - Support: 18
#
# Rule: If a person buys 70000 and 30000 they will also buy 90000
#  - Confidence: 0.052
#  - Support: 30
#
# Rule: If a person buys 200000 and 170000 they will also buy 150000
#  - Confidence: 0.037
#  - Support: 7
#
# Rule: If a person buys 120000 and 50000 they will also buy 70000
#  - Confidence: 0.056
#  - Support: 20
#
# Rule: If a person buys 20000 and 160000 they will also buy 150000
#  - Confidence: 0.038
#  - Support: 9
#
# Rule: If a person buys 140000 and 20000 they will also buy 60000
#  - Confidence: 0.050
#  - Support: 11
#
# Rule: If a person buys 200000 and 140000 they will also buy 110000
#  - Confidence: 0.059
#  - Support: 10
#
# Rule: If a person buys 160000 and 40000 they will also buy 170000
#  - Confidence: 0.031
#  - Support: 8
#
# Rule: If a person buys 180000 and 60000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 170000 and 200000 they will also buy 60000
#  - Confidence: 0.053
#  - Support: 10
#
# Rule: If a person buys 20000 and 170000 they will also buy 110000
#  - Confidence: 0.059
#  - Support: 11
#
# Rule: If a person buys 130000 and 200000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 17
#
# Rule: If a person buys 40000 and 30000 they will also buy 170000
#  - Confidence: 0.020
#  - Support: 11
#
# Rule: If a person buys 200000 and 40000 they will also buy 180000
#  - Confidence: 0.020
#  - Support: 8
#
# ...
#  - Confidence: 0.022
#  - Support: 3
#
# Rule: If a person buys 160000 and 60000 they will also buy 140000
#  - Confidence: 0.033
#  - Support: 9
#
# Rule: If a person buys 60000 and 110000 they will also buy 120000
#  - Confidence: 0.041
#  - Support: 19
#
# Rule: If a person buys 50000 and 120000 they will also buy 80000
#  - Confidence: 0.056
#  - Support: 20
#
# Rule: If a person buys 190000 and 100000 they will also buy 120000
#  - Confidence: 0.042
#  - Support: 12
#
# Rule: If a person buys 50000 and 130000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 21
#
# Rule: If a person buys 60000 and 180000 they will also buy 120000
#  - Confidence: 0.051
#  - Support: 7
#
# Rule: If a person buys 20000 and 90000 they will also buy 110000
#  - Confidence: 0.056
#  - Support: 23
#
# Rule: If a person buys 120000 and 200000 they will also buy 150000
#  - Confidence: 0.035
#  - Support: 10
#
# Rule: If a person buys 50000 and 30000 they will also buy 100000
#  - Confidence: 0.047
#  - Support: 24
#
# Rule: If a person buys 180000 and 130000 they will also buy 20000
#  - Confidence: 0.046
#  - Support: 7
#
# Rule: If a person buys 80000 and 160000 they will also buy 200000
#  - Confidence: 0.055
#  - Support: 14
#
# Rule: If a person buys 70000 and 110000 they will also buy 120000
#  - Confidence: 0.038
#  - Support: 20
#
# Rule: If a person buys 190000 and 140000 they will also buy 150000
#  - Confidence: 0.039
#  - Support: 8
#
# Rule: If a person buys 100000 and 90000 they will also buy 180000
#  - Confidence: 0.018
#  - Support: 8
#
# Rule: If a person buys 130000 and 110000 they will also buy 20000
#  - Confidence: 0.051
#  - Support: 19
#
# Rule: If a person buys 190000 and 200000 they will also buy 130000
#  - Confidence: 0.044
#  - Support: 12
#
# Rule: If a person buys 190000 and 110000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 20
#
# Rule: If a person buys 150000 and 140000 they will also buy 20000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 130000 and 90000 they will also buy 20000
#  - Confidence: 0.050
#  - Support: 17
#
# Rule: If a person buys 60000 and 170000 they will also buy 140000
#  - Confidence: 0.021
#  - Support: 5
#
# Rule: If a person buys 160000 and 20000 they will also buy 200000
#  - Confidence: 0.055
#  - Support: 13
#
# Rule: If a person buys 190000 and 30000 they will also buy 50000
#  - Confidence: 0.050
#  - Support: 16
#
# Rule: If a person buys 120000 and 140000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 10
#
# Rule: If a person buys 140000 and 30000 they will also buy 70000
#  - Confidence: 0.055
#  - Support: 14
#
# Rule: If a person buys 20000 and 160000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 14
#
# Rule: If a person buys 180000 and 170000 they will also buy 140000
#  - Confidence: 0.029
#  - Support: 2
#
# Rule: If a person buys 130000 and 100000 they will also buy 50000
#  - Confidence: 0.059
#  - Support: 18
#
# Rule: If a person buys 110000 and 20000 they will also buy 190000
#  - Confidence: 0.045
#  - Support: 19
#
# Rule: If a person buys 120000 and 200000 they will also buy 180000
#  - Confidence: 0.024
#  - Support: 7
#
# Rule: If a person buys 200000 and 80000 they will also buy 130000
#  - Confidence: 0.043
#  - Support: 16
#
# Rule: If a person buys 140000 and 30000 they will also buy 80000
#  - Confidence: 0.051
#  - Support: 13
#
# Rule: If a person buys 130000 and 70000 they will also buy 50000
#  - Confidence: 0.054
#  - Support: 21
#
# Rule: If a person buys 160000 and 180000 they will also buy 200000
#  - Confidence: 0.059
#  - Support: 7
#
# Rule: If a person buys 150000 and 170000 they will also buy 140000
#  - Confidence: 0.033
#  - Support: 5
#
# Rule: If a person buys 190000 and 40000 they will also buy 80000
#  - Confidence: 0.053
#  - Support: 18
#
# Rule: If a person buys 70000 and 150000 they will also buy 170000
#  - Confidence: 0.031
#  - Support: 9
#
# Rule: If a person buys 140000 and 30000 they will also buy 180000
#  - Confidence: 0.020
#  - Support: 5
#
# Rule: If a person buys 180000 and 160000 they will also buy 60000
#  - Confidence: 0.059
#  - Support: 7
#
# Rule: If a person buys 90000 and 30000 they will also buy 20000
#  - Confidence: 0.042
#  - Support: 23
#
# Rule: If a person buys 190000 and 180000 they will also buy 20000
#  - Confidence: 0.059
#  - Support: 7
#
# Rule: If a person buys 120000 and 20000 they will also buy 30000
#  - Confidence: 0.055
#  - Support: 16
#
# Rule: If a person buys 90000 and 50000 they will also buy 110000
#  - Confidence: 0.051
#  - Support: 26
#
# Rule: If a person buys 80000 and 120000 they will also buy 170000
#  - Confidence: 0.032
#  - Support: 12
#
# Rule: If a person buys 200000 and 50000 they will also buy 140000
#  - Confidence: 0.024
#  - Support: 9
#
# Rule: If a person buys 130000 and 20000 they will also buy 110000
#  - Confidence: 0.056
#  - Support: 19
#
# Rule: If a person buys 110000 and 50000 they will also buy 30000
#  - Confidence: 0.057
#  - Support: 27
#
# Rule: If a person buys 200000 and 140000 they will also buy 130000
#  - Confidence: 0.047
#  - Support: 8
#
# Rule: If a person buys 40000 and 100000 they will also buy 200000
#  - Confidence: 0.045
#  - Support: 19
#
# Rule: If a person buys 200000 and 170000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 11
#
# Rule: If a person buys 70000 and 170000 they will also buy 100000
#  - Confidence: 0.042
#  - Support: 10
#
# Rule: If a person buys 190000 and 90000 they will also buy 200000
#  - Confidence: 0.046
#  - Support: 14
#
# Rule: If a person buys 120000 and 110000 they will also buy 180000
#  - Confidence: 0.020
#  - Support: 7
#
# Rule: If a person buys 30000 and 100000 they will also buy 130000
#  - Confidence: 0.038
#  - Support: 18
#
# Rule: If a person buys 120000 and 200000 they will also buy 140000
#  - Confidence: 0.024
#  - Support: 7
#
# Rule: If a person buys 40000 and 100000 they will also buy 160000
#  - Confidence: 0.035
#  - Support: 15
#
# Rule: If a person buys 200000 and 160000 they will also buy 110000
#  - Confidence: 0.051
#  - Support: 14
#
# Rule: If a person buys 80000 and 70000 they will also buy 60000
#  - Confidence: 0.046
#  - Support: 26
#
# Rule: If a person buys 140000 and 120000 they will also buy 20000
#  - Confidence: 0.053
#  - Support: 9
#
# Rule: If a person buys 90000 and 60000 they will also buy 160000
#  - Confidence: 0.034
#  - Support: 16
#
# Rule: If a person buys 60000 and 130000 they will also buy 110000
#  - Confidence: 0.059
#  - Support: 19
#
# Rule: If a person buys 80000 and 20000 they will also buy 50000
#  - Confidence: 0.056
#  - Support: 24
#
# Rule: If a person buys 90000 and 120000 they will also buy 140000
#  - Confidence: 0.026
#  - Support: 10
#
# Rule: If a person buys 60000 and 200000 they will also buy 140000
#  - Confidence: 0.023
#  - Support: 9
#
# Rule: If a person buys 60000 and 40000 they will also buy 190000
#  - Confidence: 0.034
#  - Support: 17
#
# Rule: If a person buys 40000 and 100000 they will also buy 90000
#  - Confidence: 0.054
#  - Support: 23
#
# Rule: If a person buys 120000 and 190000 they will also buy 180000
#  - Confidence: 0.024
#  - Support: 6
#
# Rule: If a person buys 20000 and 120000 they will also buy 90000
#  - Confidence: 0.055
#  - Support: 16
#
# Rule: If a person buys 90000 and 110000 they will also buy 140000
#  - Confidence: 0.027
#  - Support: 13
#
# Rule: If a person buys 90000 and 170000 they will also buy 100000
#  - Confidence: 0.046
#  - Support: 11
#
# Rule: If a person buys 200000 and 80000 they will also buy 30000
#  - Confidence: 0.056
#  - Support: 21
#
# Rule: If a person buys 190000 and 30000 they will also buy 20000
#  - Confidence: 0.056
#  - Support: 18
#
# Rule: If a person buys 100000 and 20000 they will also buy 150000
#  - Confidence: 0.031
#  - Support: 11
#
# Rule: If a person buys 200000 and 170000 they will also buy 100000
#  - Confidence: 0.048
#  - Support: 9
#
# Rule: If a person buys 180000 and 80000 they will also buy 170000
#  - Confidence: 0.022
#  - Support: 3
#
# Rule: If a person buys 180000 and 170000 they will also buy 60000
#  - Confidence: 0.044
#  - Support: 3
#
# Rule: If a person buys 200000 and 80000 they will also buy 120000
#  - Confidence: 0.043
#  - Support: 16
#
# Rule: If a person buys 180000 and 100000 they will also buy 150000
#  - Confidence: 0.037
#  - Support: 5
#
# Rule: If a person buys 90000 and 190000 they will also buy 110000
#  - Confidence: 0.056
#  - Support: 17
#
# Rule: If a person buys 190000 and 80000 they will also buy 30000
#  - Confidence: 0.052
#  - Support: 16
#
# Rule: If a person buys 140000 and 50000 they will also buy 40000
#  - Confidence: 0.059
#  - Support: 13
#
# Rule: If a person buys 150000 and 140000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 20000 and 110000 they will also buy 50000
#  - Confidence: 0.052
#  - Support: 22
#
# Rule: If a person buys 100000 and 150000 they will also buy 180000
#  - Confidence: 0.025
#  - Support: 5
#
# Rule: If a person buys 200000 and 120000 they will also buy 150000
#  - Confidence: 0.035
#  - Support: 10
#
# Rule: If a person buys 120000 and 190000 they will also buy 130000
#  - Confidence: 0.051
#  - Support: 13
#
# Rule: If a person buys 30000 and 110000 they will also buy 160000
#  - Confidence: 0.028
#  - Support: 14
#
# Rule: If a person buys 40000 and 170000 they will also buy 60000
#  - Confidence: 0.054
#  - Support: 12
#
# Rule: If a person buys 100000 and 110000 they will also buy 80000
#  - Confidence: 0.052
#  - Support: 22
#
# Rule: If a person buys 190000 and 90000 they will also buy 170000
#  - Confidence: 0.023
#  - Support: 7
#
# Rule: If a person buys 80000 and 100000 they will also buy 140000
#  - Confidence: 0.029
#  - Support: 12
#
# Rule: If a person buys 40000 and 160000 they will also buy 130000
#  - Confidence: 0.055
#  - Support: 14
#
# Rule: If a person buys 200000 and 170000 they will also buy 70000
#  - Confidence: 0.053
#  - Support: 10
#
# Rule: If a person buys 160000 and 80000 they will also buy 40000
#  - Confidence: 0.059
#  - Support: 15
#
# Rule: If a person buys 190000 and 100000 they will also buy 80000
#  - Confidence: 0.052
#  - Support: 15
#
# Rule: If a person buys 200000 and 70000 they will also buy 90000
#  - Confidence: 0.049
#  - Support: 21
#
# Rule: If a person buys 50000 and 30000 they will also buy 40000
#  - Confidence: 0.055
#  - Support: 28
#
# Rule: If a person buys 120000 and 180000 they will also buy 50000
#  - Confidence: 0.059
#  - Support: 7
#
# Rule: If a person buys 30000 and 50000 they will also buy 170000
#  - Confidence: 0.025
#  - Support: 13
#
# Rule: If a person buys 170000 and 30000 they will also buy 180000
#  - Confidence: 0.016
#  - Support: 4
#
# Rule: If a person buys 40000 and 100000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 25
#
# Rule: If a person buys 20000 and 180000 they will also buy 170000
#  - Confidence: 0.025
#  - Support: 3
#
# Rule: If a person buys 60000 and 20000 they will also buy 110000
#  - Confidence: 0.056
#  - Support: 21
#
# Rule: If a person buys 170000 and 180000 they will also buy 100000
#  - Confidence: 0.044
#  - Support: 3
#
# Rule: If a person buys 170000 and 120000 they will also buy 60000
#  - Confidence: 0.059
#  - Support: 12
#
# Rule: If a person buys 20000 and 110000 they will also buy 120000
#  - Confidence: 0.040
#  - Support: 17
#
# Rule: If a person buys 70000 and 160000 they will also buy 200000
#  - Confidence: 0.055
#  - Support: 14
#
# Rule: If a person buys 190000 and 120000 they will also buy 20000
#  - Confidence: 0.051
#  - Support: 13
#
# Rule: If a person buys 100000 and 140000 they will also buy 70000
#  - Confidence: 0.055
#  - Support: 13
#
# Rule: If a person buys 190000 and 50000 they will also buy 140000
#  - Confidence: 0.040
#  - Support: 11
#
# Rule: If a person buys 50000 and 160000 they will also buy 20000
#  - Confidence: 0.051
#  - Support: 14
#
# Rule: If a person buys 170000 and 100000 they will also buy 90000
#  - Confidence: 0.054
#  - Support: 11
#
# Rule: If a person buys 150000 and 170000 they will also buy 60000
#  - Confidence: 0.052
#  - Support: 8
#
# Rule: If a person buys 190000 and 80000 they will also buy 150000
#  - Confidence: 0.033
#  - Support: 10
#
# Rule: If a person buys 140000 and 50000 they will also buy 190000
#  - Confidence: 0.050
#  - Support: 11
#
# Rule: If a person buys 180000 and 170000 they will also buy 90000
#  - Confidence: 0.044
#  - Support: 3
#
# Rule: If a person buys 120000 and 30000 they will also buy 140000
#  - Confidence: 0.024
#  - Support: 10
#
# Rule: If a person buys 100000 and 30000 they will also buy 140000
#  - Confidence: 0.029
#  - Support: 14
#
# Rule: If a person buys 40000 and 190000 they will also buy 30000
#  - Confidence: 0.050
#  - Support: 17
#
# Rule: If a person buys 100000 and 90000 they will also buy 200000
#  - Confidence: 0.045
#  - Support: 20
#
# Rule: If a person buys 160000 and 190000 they will also buy 200000
#  - Confidence: 0.053
#  - Support: 10
#
# Rule: If a person buys 130000 and 140000 they will also buy 50000
#  - Confidence: 0.059
#  - Support: 11
#
# Rule: If a person buys 200000 and 180000 they will also buy 90000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 160000 and 70000 they will also buy 80000
#  - Confidence: 0.059
#  - Support: 15
#
# Rule: If a person buys 170000 and 160000 they will also buy 190000
#  - Confidence: 0.044
#  - Support: 6
#
# Rule: If a person buys 80000 and 110000 they will also buy 20000
#  - Confidence: 0.050
#  - Support: 23
#
# Rule: If a person buys 90000 and 80000 they will also buy 110000
#  - Confidence: 0.053
#  - Support: 25
#
# Rule: If a person buys 120000 and 150000 they will also buy 170000
#  - Confidence: 0.036
#  - Support: 8
#
# Rule: If a person buys 120000 and 20000 they will also buy 130000
#  - Confidence: 0.048
#  - Support: 14
#
# Rule: If a person buys 20000 and 60000 they will also buy 200000
#  - Confidence: 0.045
#  - Support: 17
#
# Rule: If a person buys 170000 and 180000 they will also buy 60000
#  - Confidence: 0.044
#  - Support: 3
#
# Rule: If a person buys 50000 and 140000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 13
#
# Rule: If a person buys 140000 and 110000 they will also buy 80000
#  - Confidence: 0.050
#  - Support: 11
#
# Rule: If a person buys 40000 and 140000 they will also buy 110000
#  - Confidence: 0.055
#  - Support: 13
#
# Rule: If a person buys 140000 and 180000 they will also buy 160000
#  - Confidence: 0.059
#  - Support: 5
#
# Rule: If a person buys 20000 and 200000 they will also buy 190000
#  - Confidence: 0.046
#  - Support: 15
#
# Rule: If a person buys 170000 and 60000 they will also buy 100000
#  - Confidence: 0.050
#  - Support: 12
#
# Rule: If a person buys 100000 and 170000 they will also buy 40000
#  - Confidence: 0.049
#  - Support: 10
#
# Rule: If a person buys 50000 and 150000 they will also buy 80000
#  - Confidence: 0.055
#  - Support: 15
#
# Rule: If a person buys 150000 and 30000 they will also buy 120000
#  - Confidence: 0.051
#  - Support: 13
#
# Rule: If a person buys 160000 and 150000 they will also buy 100000
#  - Confidence: 0.059
#  - Support: 10
#
# Rule: If a person buys 40000 and 170000 they will also buy 100000
#  - Confidence: 0.045
#  - Support: 10
#
# Rule: If a person buys 200000 and 130000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 17
#
# Rule: If a person buys 120000 and 100000 they will also buy 130000
#  - Confidence: 0.041
#  - Support: 14
#
# Rule: If a person buys 50000 and 90000 they will also buy 190000
#  - Confidence: 0.029
#  - Support: 15
#
# Rule: If a person buys 120000 and 140000 they will also buy 60000
#  - Confidence: 0.059
#  - Support: 10
#
# Rule: If a person buys 120000 and 160000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 12
#
# Rule: If a person buys 190000 and 100000 they will also buy 90000
#  - Confidence: 0.052
#  - Support: 15
#
# Rule: If a person buys 70000 and 50000 they will also buy 120000
#  - Confidence: 0.037
#  - Support: 20
#
# Rule: If a person buys 60000 and 180000 they will also buy 110000
#  - Confidence: 0.059
#  - Support: 8
#
# Rule: If a person buys 80000 and 180000 they will also buy 20000
#  - Confidence: 0.051
#  - Support: 7
#
# Rule: If a person buys 20000 and 80000 they will also buy 110000
#  - Confidence: 0.054
#  - Support: 23
#
# Rule: If a person buys 110000 and 130000 they will also buy 190000
#  - Confidence: 0.043
#  - Support: 16
#
# Rule: If a person buys 100000 and 140000 they will also buy 30000
#  - Confidence: 0.059
#  - Support: 14
#
# Rule: If a person buys 30000 and 150000 they will also buy 160000
#  - Confidence: 0.039
#  - Support: 10
#
# Rule: If a person buys 150000 and 190000 they will also buy 140000
#  - Confidence: 0.047
#  - Support: 8

# %% [markdown]
# #### Create a function that will print out the rules in a readable format

# %%
def print_rule(premiseA, premiseB, conclusion):
    print("Rule: If a person buys {0} and {1} they will also buy {2}".format(premiseA, premiseB, conclusion))
    print(" - Confidence: {0:.3f}".format(confidence[(premiseA, premiseB, conclusion)]))
    print(" - Support: {0}".format(support[(premiseA, premiseB, conclusion)]))
    print("")

# %% [markdown]
# #### Test the function

# %% [markdown]
# Call the print_rule function to report the support confidence statistics on the Rule: If a person buys cheese and apples, then they are likely to purchase bananas.

# %%
print_rule(20000, 40000, 60000)
# Out:
# Rule: If a person buys 20000 and 40000 they will also buy 60000
#  - Confidence: 0.050
#  - Support: 22

# %% [markdown]
# ### Part D: Sort the rules derived in Part C according to support and print the top 5

# %%
from operator import itemgetter
sorted_support = sorted(support.items(), key=itemgetter(1), reverse=True)
sorted_confidence = sorted(confidence.items(), key=itemgetter(1), reverse=True)

for index in range(5):
    print("Rule #{0}".format(index + 1))
    (premiseA, premiseB, conclusion) = sorted_support[index][0]
    print_rule(premiseA, premiseB, conclusion)
# Out:
# Rule #1
# Rule: If a person buys 40000 and 70000 they will also buy 80000
#  - Confidence: 0.054
#  - Support: 31
#
# Rule #2
# Rule: If a person buys 70000 and 80000 they will also buy 40000
#  - Confidence: 0.055
#  - Support: 31
#
# Rule #3
# Rule: If a person buys 40000 and 80000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 31
#
# Rule #4
# Rule: If a person buys 80000 and 40000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 31
#
# Rule #5
# Rule: If a person buys 80000 and 70000 they will also buy 40000
#  - Confidence: 0.055
#  - Support: 31

# %% [markdown]
# ### Part E: Sort the rules derived in Part C according to confidence and print the top 5

# %%
from operator import itemgetter
sorted_confidence = sorted(confidence.items(), key=itemgetter(1), reverse=True)
for index in range(5):
    print("Rule #{0}".format(index + 1))
    (premiseA, premiseB, conclusion) = sorted_confidence[index][0]
    print_rule(premiseA, premiseB, conclusion)
# Out:
# Rule #1
# Rule: If a person buys 190000 and 100000 they will also buy 110000
#  - Confidence: 0.059
#  - Support: 17
#
# Rule #2
# Rule: If a person buys 140000 and 200000 they will also buy 20000
#  - Confidence: 0.059
#  - Support: 10
#
# Rule #3
# Rule: If a person buys 110000 and 180000 they will also buy 130000
#  - Confidence: 0.059
#  - Support: 9
#
# Rule #4
# Rule: If a person buys 140000 and 130000 they will also buy 80000
#  - Confidence: 0.059
#  - Support: 11
#
# Rule #5
# Rule: If a person buys 130000 and 40000 they will also buy 70000
#  - Confidence: 0.059
#  - Support: 21

# %% [markdown]
# ### Part F: What recommendations would you make to the manager of the store where this data has come from, based on this analysis, and why?

# %% [markdown]
# ### Part G: Prepare the data in the transaction dataset, and then analyse it in a similar way (as above). Use the results to make recommendations to the manager of the store where the data was collected.
